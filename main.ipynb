# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from datetime import date, timedelta
# %matplotlib inline

# %%
df=pd.read_excel('Mobile Sandesh Brand 4 Data for Challenge (1).xlsx')

# %%
df
# Out:
#    Anonymised Variables       Unnamed: 1                Unnamed: 2  \
# 0                    10               11                        12
# 1         Generic Group    Generic Brand  Generic Product Category
# 2             Segment 2  Sandesh Brand 4                    Mobile
# 3             Segment 2  Sandesh Brand 4                    Mobile
# 4             Segment 2  Sandesh Brand 4                    Mobile
# 5             Segment 2  Sandesh Brand 4                    Mobile
# 6             Segment 2  Sandesh Brand 4                    Mobile
# 7             Segment 2  Sandesh Brand 4                    Mobile
# 8             Segment 2  Sandesh Brand 4                    Mobile
# 9             Segment 2  Sandesh Brand 4                    Mobile
# 10            Segment 2  Sandesh Brand 4                    Mobile
# 11            Segment 2  Sandesh Brand 4                    Mobile
#
#                    Unnamed: 3              Unnamed: 4        Unnamed: 5  \
# ...

# %%
type(df.loc[1][11])
# Out:
# datetime.datetime

# %%
#from sklearn.utils import check_arrays
def mean_absolute_percentage_error(y_true, y_pred): 
  #  y_true, y_pred = check_arrays(y_true, y_pred)

    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def robustness_linear(lm,w,m):
    a1=[]
    a2=[]
    a3=[]
    a4=[]
    a5=[]
    a6=[]
    a7=[]
    a8=[]
    a9=[]
    a10=[]
    a11=[]
    a12=[]
   # if(m==1):
    g = [i for i in range(0,len(d)-12)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-12])
    gg = [i for i in range(0,len(d))]
    gg = np.array(gg).reshape(-1,1)
    a1 = lm.predict(gg[:]) - w
    a1 = a1[len(a1)-12:]
    
    g = [i for i in range(0,len(d)-13)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-13])
    gg = [i for i in range(0,len(d)-1)]
    gg = np.array(gg).reshape(-1,1)
    a2 = lm.predict(gg[:-1]) - w
    a2 = a2[len(a2)-12:]
    
    
    g = [i for i in range(0,len(d)-14)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-14])
    gg = [i for i in range(0,len(d)-2)]
    gg = np.array(gg).reshape(-1,1)
    a3 = lm.predict(gg[:-2]) - w
    a3 = a3[len(a3)-12:]
    
    g = [i for i in range(0,len(d)-15)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-15])
    gg = [i for i in range(0,len(d)-3)]
    gg = np.array(gg).reshape(-1,1)
    a4 = lm.predict(gg[:-3]) - w
    a4 = a4[len(a4)-12:] 
        
    
    
        
    g = [i for i in range(0,len(d)-16)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-16])
    gg = [i for i in range(0,len(d)-4)]
    gg = np.array(gg).reshape(-1,1)    
    a5 = lm.predict(gg[:-4]) - w
    a5 = a5[len(a5)-12:]   
        
    
    g = [i for i in range(0,len(d)-17)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-17])
    gg = [i for i in range(0,len(d)-5)]
    gg = np.array(gg).reshape(-1,1)
    a6 = lm.predict(gg[:-5]) - w
    a6 = a6[len(a6)-12:]   
        
    g = [i for i in range(0,len(d)-18)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-18])
    gg = [i for i in range(0,len(d)-6)]
    gg = np.array(gg).reshape(-1,1)
    a7 = lm.predict(gg[:-6]) - w
    a7 = a7[len(a7)-12:]  
        
    g = [i for i in range(0,len(d)-19)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-19])
    gg = [i for i in range(0,len(d)-7)]
    gg = np.array(gg).reshape(-1,1)
    a8 = lm.predict(gg[:-7]) - w
    a8 = a8[len(a8)-12:]   
        
    g = [i for i in range(0,len(d)-20)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-20])
    gg = [i for i in range(0,len(d)-8)]
    gg = np.array(gg).reshape(-1,1)
    a9 = lm.predict(gg[:-8]) - w
    a9 = a9[len(a9)-12:]  
    
    g = [i for i in range(0,len(d)-21)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-21])
    gg = [i for i in range(0,len(d)-9)]
    gg = np.array(gg).reshape(-1,1)
    a10 = lm.predict(gg[:-9]) - w
    a10 = a10[len(a10)-12:]   
        
    g = [i for i in range(0,len(d)-22)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-22])
    gg = [i for i in range(0,len(d)-10)]
    gg = np.array(gg).reshape(-1,1)
    a11 = lm.predict(gg[:-10]) - w
    a11 = a11[len(a11)-12:]   
        
    g = [i for i in range(0,len(d)-23)]
    g = np.array(g).reshape(-1,1)
    model = lm.fit(g,l[:-23])
    gg = [i for i in range(0,len(d)-11)]
    gg = np.array(gg).reshape(-1,1)
    a12 = lm.predict(gg[:-11]) - w
    a12 = a12[len(a12)-12:]
    m = m-1
    
    for t in range(0,len(a1)):
        rob_1.iloc[m,t] = a1[t]
        rob_2.iloc[m,t] = a2[t]
        rob_3.iloc[m,t] = a3[t]
        rob_4.iloc[m,t] = a4[t]
        rob_5.iloc[m,t] = a5[t]
        rob_6.iloc[m,t] = a6[t]
        rob_7.iloc[m,t] = a7[t]
        rob_8.iloc[m,t] = a8[t]
        rob_9.iloc[m,t] = a9[t]
        rob_10.iloc[m,t] = a10[t]
        rob_11.iloc[m,t] = a11[t]
        rob_12.iloc[m,t] = a12[t]
    
 #   return(a1,a2,a3,a4,a5,a6)

# %%
def robustness_(lm,w,m,p,q,a):  #w is small parameter added because of the distortion created by anomalies of year 2015 
    a1=[]                       #m is the order number ranging from 1 to 10
    a2=[]                       #a is the start time from where we want to fit the model here it is taken 0 
    a3=[]                       #p and q are model parameters
    a4=[]
    a5=[]
    a6=[]
    a7=[]
    a8=[]
    a9=[]
    a10=[]
    a11=[]
    a12=[]
   # if(m==1):

    model=sm.tsa.statespace.SARIMAX(d['sales'][a:60],order=p,seasonal_order=q)
    model_fit=model.fit()
    a1 =model_fit.predict(start=60,end=71,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:59],order=p,seasonal_order=q)
    model_fit=model.fit()
    a2=model_fit.predict(start=59,end=70,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:58],order=p,seasonal_order=q)
    model_fit=model.fit()
    a3=model_fit.predict(start=58,end=69,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:57],order=p,seasonal_order=q)
    model_fit=model.fit()
    a4=model_fit.predict(start=57,end=68,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:56],order=p,seasonal_order=q)
    model_fit=model.fit()
    a5=model_fit.predict(start=56,end=67,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:55],order=p,seasonal_order=q)
    model_fit=model.fit()
    a6=model_fit.predict(start=55,end=66,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:54],order=p,seasonal_order=q)
    model_fit=model.fit()
    a7=model_fit.predict(start=54,end=65,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:53],order=p,seasonal_order=q)
    model_fit=model.fit()
    a8=model_fit.predict(start=53,end=64,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:52],order=p,seasonal_order=q)
    model_fit=model.fit()
    a9=model_fit.predict(start=52,end=63,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:51],order=p,seasonal_order=q)
    model_fit=model.fit()
    a10=model_fit.predict(start=51,end=62,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:50],order=p,seasonal_order=q)
    model_fit=model.fit()
    a11=model_fit.predict(start=50,end=61,dynamic=False)+w
    
    model=sm.tsa.statespace.SARIMAX(d['sales'][a:49],order=p,seasonal_order=q)
    model_fit=model.fit()
    a12=model_fit.predict(start=49,end=60,dynamic=False)+w
    
        
    
    m = m-1
    
    for t in range(0,len(a1)):
        rob_1.iloc[m,t] = a1[t]
        rob_2.iloc[m,t] = a2[t]
        rob_3.iloc[m,t] = a3[t]
        rob_4.iloc[m,t] = a4[t]
        rob_5.iloc[m,t] = a5[t]
        rob_6.iloc[m,t] = a6[t]
        rob_7.iloc[m,t] = a7[t]
        rob_8.iloc[m,t] = a8[t]
        rob_9.iloc[m,t] = a9[t]
        rob_10.iloc[m,t] = a10[t]
        rob_11.iloc[m,t] = a11[t]
        rob_12.iloc[m,t] = a12[t]
    
 #   return(a1,a2,a3,a4,a5,a6)

# %%
yyy=[]
for i in range(2,len(df)):
    yy=''
    for ii in range(3,6):
        yy =yy + ' ' +df.iloc[i][ii]
    yyy.append(yy)
yyy[1]
# Out:
# ' Leopard Volume Leavers'

# %%
ll = []
for i in range(0,72):
    ll.append(df.loc[1][i+9])
ll[0]
# Out:
# datetime.datetime(2014, 4, 1, 0, 0)

# %%
rob_1 = pd.DataFrame(columns = ll[60:72])
rob_2 = pd.DataFrame(columns = ll[59:71])
rob_3 = pd.DataFrame(columns = ll[58:70])
rob_4 = pd.DataFrame(columns = ll[57:69])
rob_5 = pd.DataFrame(columns = ll[56:68])
rob_6 = pd.DataFrame(columns = ll[55:67])
rob_7 = pd.DataFrame(columns = ll[54:66])
rob_8 = pd.DataFrame(columns = ll[53:65])
rob_9 = pd.DataFrame(columns = ll[52:64])
rob_10 = pd.DataFrame(columns = ll[51:63])
rob_11 = pd.DataFrame(columns = ll[50:62])
rob_12 = pd.DataFrame(columns = ll[49:61])

# %%
rob_1['Anonymised Variables'] = yyy
rob_2['Anonymised Variables'] = yyy
rob_3['Anonymised Variables'] = yyy
rob_4['Anonymised Variables'] = yyy
rob_5['Anonymised Variables'] = yyy
rob_6['Anonymised Variables'] = yyy
rob_7['Anonymised Variables'] = yyy
rob_8['Anonymised Variables'] = yyy
rob_9['Anonymised Variables'] = yyy
rob_10['Anonymised Variables'] = yyy
rob_11['Anonymised Variables'] = yyy
rob_12['Anonymised Variables'] = yyy

# %%
rob_1
# Out:
#   2019-04-01 00:00:00 2019-05-01 00:00:00 2019-06-01 00:00:00  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 5                 NaN                 NaN                 NaN
# 6                 NaN                 NaN                 NaN
# 7                 NaN                 NaN                 NaN
# 8                 NaN                 NaN                 NaN
# 9                 NaN                 NaN                 NaN
#
#   2019-07-01 00:00:00 2019-08-01 00:00:00 2019-09-01 00:00:00  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# ...

# %%
#1

# %%
yyy[0]
# Out:
# ' Leopard Volume Closing Base'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])

# %%
d['time']=ll

# %%
d.set_index('time',inplace=True)

# %%
l = []
for i in range(0,72):
    l.append(df.loc[2][i+9])
l[0]
# Out:
# 1.6936535906196926

# %%
d['sales']=l
d
# Out:
#                sales
# time
# 2014-04-01  1.693654
# 2014-05-01  1.660725
# 2014-06-01  1.595102
# 2014-07-01  1.538099
# 2014-08-01  1.474851
# 2014-09-01  1.453945
# 2014-10-01  1.438345
# 2014-11-01  1.364629
# 2014-12-01  1.272118
# 2015-01-01  1.169461
# 2015-02-01  1.072111
# 2015-03-01  1.897355
# 2015-04-01  1.560414
# 2015-05-01  1.209779
# 2015-06-01  0.862194
# 2015-07-01  0.789299
# 2015-08-01  0.708194
# 2015-09-01  0.653846
# 2015-10-01  0.603968
# 2015-11-01  0.554619
# 2015-12-01  0.263518
# 2016-01-01  0.236512
# 2016-02-01  0.152387
# 2016-03-01  0.155583
# 2016-04-01  0.156903
# 2016-05-01  0.109283
# 2016-06-01  0.135556
# 2016-07-01  0.101337
# 2016-08-01  0.140453
# 2016-09-01  0.250792
# ...              ...
# 2017-10-01  0.081897
# 2017-11-01  0.078554
# 2017-12-01  0.025187
# 2018-01-01 -0.090694
# 2018-02-01 -0.228391
# 2018-03-01 -0.362129
# 2018-04-01 -0.429893
# 2018-05-01 -0.505720
# 2018-06-01 -0.583922
# 2018-07-01 -0.664676
# 2018-08-01 -0.754695
# ...

# %%
d.describe()
# Out:
#            sales
# count  72.000000
# mean    0.025376
# std     0.983064
# min    -1.678842
# 25%    -0.886366
# 50%     0.153985
# 75%     0.616438
# max     1.897355

# %%
#Visualize the Data
d.plot()

# %%
from sklearn import linear_model
lm = linear_model.LinearRegression()
g = [i for i in range(0,len(d)-6)]
g = np.array(g)
g = g.reshape(-1,1)
model = lm.fit(g,l[:-6])

# %%
gg = [i for i in range(0,len(d)+6)]
gg = np.array(gg).reshape(-1,1)
#gg = gg.reshape(-1,1)
x1 = lm.predict(gg) - .035
#print(predictions)[0:5]
plt.plot(x1[:len(d)]-l)

# %%
plt.plot(x1[:])

# %%
print(mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(x1[66:72])))
# Out:
# 2.2510833423740477

# %%
robustness_linear(lm,-.035,1)

# %%
len(x1)
# Out:
# 78

# %%
#2

# %%
yyy[1]
# Out:
# ' Leopard Volume Leavers'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
d.set_index('time',inplace=True)

# %%
l = []
for i in range(0,72):
    l.append(df.loc[3][i+9])
l[0]
d['sales']=l
print(d)
d.describe()
# Out:
#                sales
# time
# 2014-04-01  1.468436
# 2014-05-01  1.005606
# 2014-06-01  1.381582
# 2014-07-01  1.391492
# 2014-08-01  0.910591
# 2014-09-01  2.095064
# 2014-10-01  2.837108
# 2014-11-01  2.651742
# 2014-12-01  3.118070
# 2015-01-01  2.293836
# 2015-02-01  1.502245
# 2015-03-01  1.573360
# 2015-04-01  0.863959
# 2015-05-01  0.486816
# 2015-06-01  0.777105
# 2015-07-01  0.303782
# 2015-08-01 -0.162846
# 2015-09-01  0.309029
# 2015-10-01  0.554434
# 2015-11-01  0.392385
# 2015-12-01  0.187595
# 2016-01-01 -0.237158
# 2016-02-01  0.654111
# 2016-03-01  0.376063
# 2016-04-01 -0.334504
# 2016-05-01 -0.211510
# 2016-06-01 -0.126988
# 2016-07-01 -0.462161
# 2016-08-01 -0.476734
# 2016-09-01 -0.546683
# ...              ...
# 2017-10-01 -0.335086
# 2017-11-01 -0.245318
# 2017-12-01 -0.000496
# 2018-01-01 -0.477899
# 2018-02-01 -0.506462
# 2018-03-01  0.099181
# 2018-04-01 -0.573497
# 2018-05-01 -0.320514
# 2018-06-01 -0.536773
# 2018-07-01 -0.457497
# 2018-08-01 -0.830560
# ...

# %%
#Visualize the Data
d.plot()

# %%
### Testing For Stationarity
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(1,0,1),seasonal_order=(2,0,0,12))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                              sales   No. Observations:                   66
# Model:             SARIMAX(1, 0, 1)x(2, 0, 0, 12)   Log Likelihood                 -29.932
# Date:                            Fri, 31 Jul 2020   AIC                             69.865
# Time:                                    23:33:14   BIC                             80.813
# ...

# %%
d['forecast']=model_fit.predict(start=0,end=78,dynamic=False)+.001
x2 = model_fit.predict(start=0,end=77,dynamic=False)+.001
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)

# %%
plt.plot(x2[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]+.85))
# Out:
# 226.42899446347312

# %%
len(x2)
# Out:
# 78

# %%
p=(1,0,1)
q=(2,0,0,12)
robustness_(model_fit,.001 , 2,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
len(d['forecast'])
# Out:
# 72

# %%
#3

# %%
yyy[2]
# Out:
# ' Leopard Volume Gross Adds'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[4][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01  1.059930
# 2014-05-01  0.948435
# 2014-06-01  0.264688
# 2014-07-01  0.604547
# 2014-08-01 -0.046961
#            sales
# count  72.000000
# mean    0.057127
# std     0.878914
# min    -1.324453
# 25%    -0.617534
# 50%    -0.010355
# 75%     0.491876
# max     3.146098

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(3,0,0),seasonal_order=(3,2,1,4))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sales   No. Observations:                   66
# Model:             SARIMAX(3, 0, 0)x(3, 2, 1, 4)   Log Likelihood                 -66.902
# Date:                           Fri, 31 Jul 2020   AIC                            149.803
# Time:                                   23:33:21   BIC                            166.287
# Sample:                               04-01-2014   HQIC                           156.224
#                                     - 09-01-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
d['forecast']=model_fit.predict(start=5,end=72,dynamic=False)-.1
#dd[['sales','forecast']].plot(figsize=(12,8))
x3 = model_fit.predict(start=0,end=77,dynamic=False)+.001
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x3[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 62.25901197295725

# %%
p=(3,0,0)
q=(3,2,1,4)
robustness_(model_fit,-.11 , 3,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#4

# %%
yyy[3]
# Out:
# ' Panther Volume Closing Base'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[5][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01 -1.614879
# 2014-05-01 -1.587873
# 2014-06-01 -1.559222
# 2014-07-01 -1.529190
# 2014-08-01 -1.502869
#            sales
# count  72.000000
# mean   -0.023918
# std     0.985767
# min    -1.614879
# 25%    -0.723774
# 50%    -0.086249
# 75%     0.800305
# max     1.699293

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(2,1,0),seasonal_order=(0,0,0,0))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ...
# Dep. Variable:                  sales   No. Observations:                   66
# Model:               SARIMAX(2, 1, 0)   Log Likelihood                 146.297
# Date:                Fri, 31 Jul 2020   AIC                           -286.594
# Time:                        23:33:35   BIC                           -280.071
# Sample:                    04-01-2014   HQIC                          -284.020
#                          - 09-01-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
d['forecast']=model_fit.predict(start=15,end=72,dynamic=False)+.001
x4 = model_fit.predict(start=0,end=77,dynamic=False)+.001
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x4[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 3.107958259832362

# %%
p=(2,1,0)
q=(0,0,0,0)
robustness_(model_fit,.001 , 4,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#5

# %%
yyy[4]
# Out:
# ' Panther Volume Leavers'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[6][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01 -1.648347
# 2014-05-01 -1.743871
# 2014-06-01 -1.608819
# 2014-07-01 -1.488042
# 2014-08-01 -1.567096
#            sales
# count  72.000000
# mean   -0.007179
# std     1.005122
# min    -1.743871
# 25%    -0.850390
# 50%    -0.169916
# 75%     0.736192
# max     2.129804

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(2,1,0),seasonal_order=(0,0,0,0))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ...
# Dep. Variable:                  sales   No. Observations:                   66
# Model:               SARIMAX(2, 1, 0)   Log Likelihood                 -23.362
# Date:                Fri, 31 Jul 2020   AIC                             52.724
# Time:                        23:33:38   BIC                             59.248
# Sample:                    04-01-2014   HQIC                            55.298
#                          - 09-01-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
d['forecast']=model_fit.predict(start=18,end=72,dynamic=False)+.1
x5 = model_fit.predict(start=0,end=77,dynamic=False)+.1
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x5[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 14.927748186837364

# %%
p=(2,1,0)
q=(0,0,0,0)
robustness_(model_fit,.1 , 5,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#6

# %%
yyy[5]
# Out:
# ' Panther Volume Gross Adds'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[7][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01 -1.389218
# 2014-05-01 -1.440901
# 2014-06-01 -1.169148
# 2014-07-01 -0.934074
# 2014-08-01 -1.181652
#            sales
# count  72.000000
# mean    0.017454
# std     0.995757
# min    -1.631794
# 25%    -0.737970
# 50%    -0.114648
# 75%     0.635172
# max     3.158053

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(1,0,0),seasonal_order=(3,0,0,6))  
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sales   No. Observations:                   66
# Model:             SARIMAX(1, 0, 0)x(3, 0, 0, 6)   Log Likelihood                 -57.431
# Date:                           Fri, 31 Jul 2020   AIC                            124.861
# Time:                                   23:33:41   BIC                            135.809
# Sample:                               04-01-2014   HQIC                           129.187
#                                     - 09-01-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
d['forecast']=model_fit.predict(start=18,end=72,dynamic=False)
x6 = model_fit.predict(start=0,end=77,dynamic=False)
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x6[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 28.749408507863212

# %%
p=(1,0,0)
q=(3,0,0,6)
robustness_(model_fit,0 , 6,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#7

# %%
yyy[6]
# Out:
# ' Hyena Volume Closing Base'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[8][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01 -1.821858
# 2014-05-01 -1.792736
# 2014-06-01 -1.770640
# 2014-07-01 -1.720922
# 2014-08-01 -1.675353
#            sales
# count  72.000000
# mean   -0.015492
# std     0.998157
# min    -1.821858
# 25%    -0.997445
# 50%     0.238032
# 75%     0.880167
# max     1.184003

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(2,1,0),seasonal_order=(0,0,0,0))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ...
# Dep. Variable:                  sales   No. Observations:                   66
# Model:               SARIMAX(2, 1, 0)   Log Likelihood                 126.791
# Date:                Fri, 31 Jul 2020   AIC                           -247.582
# Time:                        23:33:44   BIC                           -241.059
# Sample:                    04-01-2014   HQIC                          -245.009
#                          - 09-01-2019
# ...

# %%
d['forecast']=model_fit.predict(start=18,end=72,dynamic=False)-.01
x7 = model_fit.predict(start=0,end=77,dynamic=False)-.01
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x7[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 2.308117084971781

# %%
p=(2,1,0)
q=(0,0,0,0)
robustness_(model_fit,-.01 , 7,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#8

# %%
yyy[7]
# Out:
# ' Hyena Volume Leavers'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[9][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01 -1.402627
# 2014-05-01 -1.370549
# 2014-06-01 -1.101293
# 2014-07-01 -1.126566
# 2014-08-01 -1.400683
#            sales
# count  72.000000
# mean   -0.019968
# std     0.992254
# min    -1.459978
# 25%    -0.869217
# 50%    -0.127789
# 75%     0.615097
# max     2.514718

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(2,0,0),seasonal_order=(3,1,0,5))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sales   No. Observations:                   66
# Model:             SARIMAX(2, 0, 0)x(3, 1, 0, 5)   Log Likelihood                 -44.191
# Date:                           Fri, 31 Jul 2020   AIC                            100.382
# Time:                                   23:33:48   BIC                            113.047
# Sample:                               04-01-2014   HQIC                           105.346
#                                     - 09-01-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
d['forecast']=model_fit.predict(start=18,end=72,dynamic=False)-.15
x8 = model_fit.predict(start=0,end=77,dynamic=False)-.15
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x8[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 52.85936993837507

# %%
p=(2,0,0)
q=(3,1,0,5)
robustness_(model_fit,-.15, 8,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#9

# %%
yyy[8]
# Out:
# ' Hyena Volume Gross Adds'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[10][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01 -2.225802
# 2014-05-01 -1.596909
# 2014-06-01 -1.690421
# 2014-07-01 -0.400779
# 2014-08-01 -1.078997
#            sales
# count  72.000000
# mean    0.032327
# std     0.967845
# min    -2.225802
# 25%    -0.613493
# 50%    -0.106885
# 75%     0.618346
# max     2.668670

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(1,0,0),seasonal_order=(2,0,0,8))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sales   No. Observations:                   66
# Model:             SARIMAX(1, 0, 0)x(2, 0, 0, 8)   Log Likelihood                 -83.202
# Date:                           Fri, 31 Jul 2020   AIC                            174.404
# Time:                                   23:33:53   BIC                            183.163
# Sample:                               04-01-2014   HQIC                           177.865
#                                     - 09-01-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
d['forecast']=model_fit.predict(start=18,end=72,dynamic=False)
x9 = model_fit.predict(start=0,end=77,dynamic=False)
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x9[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 117.52100840557496

# %%
p=(1,0,0)
q=(2,0,0,8)
robustness_(model_fit,0 , 9,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
#10

# %%
yyy[9]
# Out:
# ' Panther - Leopard - Hyena Revenue Total Revenue'

# %%
d = []
d = pd.DataFrame(columns = ['time','sales'])
d['time']=ll
#d['launch'] = r
d.set_index('time',inplace=True)
l = []
for i in range(0,72):
    l.append(df.loc[11][i+9])
l[0]
d['sales']=l
print(d.head())
print(d.describe())
#Visualize the Data
d.plot()
plt.show()
# Out:
#                sales
# time
# 2014-04-01  0.118450
# 2014-05-01  0.273741
# 2014-06-01  0.253193
# 2014-07-01 -0.029546
# 2014-08-01  0.205257
#            sales
# count  72.000000
# mean    0.026019
# std     0.981818
# min    -5.159836
# 25%    -0.456755
# 50%     0.117589
# 75%     0.448430
# max     1.865086

# %%
model=sm.tsa.statespace.SARIMAX(d['sales'][:66],order=(2,0,0),seasonal_order=(2,2,1,4))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sales   No. Observations:                   66
# Model:             SARIMAX(2, 0, 0)x(2, 2, 1, 4)   Log Likelihood                 -89.299
# Date:                           Fri, 31 Jul 2020   AIC                            190.597
# Time:                                   23:33:56   BIC                            202.960
# Sample:                               04-01-2014   HQIC                           195.413
#                                     - 09-01-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
d['forecast']=model_fit.predict(start=0,end=72,dynamic=False)+.15
x10 = model_fit.predict(start=0,end=77,dynamic=False)+.15
#dd[['sales','forecast']].plot(figsize=(12,8))
d[['sales','forecast']].plot(figsize=(12,8))

# %%
plt.plot(x10[:])

# %%
mean_absolute_percentage_error(np.array(d['sales'][66:]), np.array(d['forecast'][66:72]))
# Out:
# 49.79717904196457

# %%
p = (2,0,0)
q = (2,2,1,4)
robustness_(model_fit,.15 , 10,p ,q ,0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
rob_1
# Out:
#   2019-04-01 00:00:00 2019-05-01 00:00:00 2019-06-01 00:00:00  \
# 0           -0.989461            -1.03331            -1.07715
# 1           -0.842153           -0.719345           -0.743796
# 2           -0.506001            0.172819          -0.0510864
# 3             1.15924             1.19119             1.21899
# 4             1.17024               1.204             1.23334
# 5           0.0934993             0.17971            0.110937
# 6             1.04048             1.07226             1.09802
# 7            0.933885            0.645681            0.106783
# 8            0.305265            0.413133           0.0452551
# 9           -0.566071            -3.23727            -0.80457
#
#   2019-07-01 00:00:00 2019-08-01 00:00:00 2019-09-01 00:00:00  \
# 0              -1.121            -1.16484            -1.20869
# 1           -0.740707           -0.919055            -0.60815
# 2           -0.144681           -0.656482           0.0471117
# ...

# %%
lll = ['Generic LookupKeys']
for i in range(66,72):
    lll.append(df.loc[1][i+9])
    
qqqqq =  df.loc[1][71+9] +timedelta(31)
lll.append((qqqqq))
qqqqq =  df.loc[1][71+9] +timedelta(61)
lll.append((qqqqq))
qqqqq =  df.loc[1][71+9] +timedelta(92)
lll.append((qqqqq))
qqqqq =  df.loc[1][71+9] +timedelta(122)
lll.append((qqqqq))
qqqqq =  df.loc[1][71+9] +timedelta(153)
lll.append((qqqqq))
qqqqq =  df.loc[1][71+9] +timedelta(184)
lll.append((qqqqq))

print(lll[2])
submission = pd.DataFrame(columns = lll)
#submission['Time Period'] = lll
# Out:
# 2019-11-01 00:00:00

# %%
submission
# Out:
# Empty DataFrame
# Columns: [Generic LookupKeys, 2019-10-01 00:00:00, 2019-11-01 00:00:00, 2019-12-01 00:00:00, 2020-01-01 00:00:00, 2020-02-01 00:00:00, 2020-03-01 00:00:00, 2020-04-01 00:00:00, 2020-05-01 00:00:00, 2020-06-01 00:00:00, 2020-07-01 00:00:00, 2020-08-01 00:00:00, 2020-09-01 00:00:00]
# Index: []

# %%
submission['Generic LookupKeys'] =yyy

# %%
submission
# Out:
#                                  Generic LookupKeys 2019-10-01 00:00:00  \
# 0                       Leopard Volume Closing Base                 NaN
# 1                            Leopard Volume Leavers                 NaN
# 2                         Leopard Volume Gross Adds                 NaN
# 3                       Panther Volume Closing Base                 NaN
# 4                            Panther Volume Leavers                 NaN
# 5                         Panther Volume Gross Adds                 NaN
# 6                         Hyena Volume Closing Base                 NaN
# 7                              Hyena Volume Leavers                 NaN
# 8                           Hyena Volume Gross Adds                 NaN
# 9   Panther - Leopard - Hyena Revenue Total Revenue                 NaN
#
#   2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# 0                 NaN                 NaN                 NaN
# ...

# %%
len(x3)
# Out:
# 78

# %%
x2[66:]
# Out:
# 2019-10-01   -0.714492
# 2019-11-01   -0.848655
# 2019-12-01   -0.824395
# 2020-01-01   -0.970099
# 2020-02-01   -0.939949
# 2020-03-01   -0.605671
# 2020-04-01   -1.059579
# 2020-05-01   -0.831402
# 2020-06-01   -0.985782
# 2020-07-01   -0.723847
# 2020-08-01   -0.802303
# 2020-09-01   -0.817037
# Freq: MS, dtype: float64

# %%
for i in range(1,len(lll)):
    submission[lll[i]][0] = x1[len(x1)-12+i-1]
    submission[lll[i]][1] = x2[len(x2)-12+i-1]
    submission[lll[i]][2] = x3[len(x3)-12+i-1]
    submission[lll[i]][3] = x4[len(x4)-12+i-1]
    submission[lll[i]][4] = x5[len(x5)-12+i-1]
    submission[lll[i]][5] = x6[len(x6)-12+i-1]
    submission[lll[i]][6] = x7[len(x7)-12+i-1]
    submission[lll[i]][7] = x8[len(x8)-12+i-1]
    submission[lll[i]][8] = x9[len(x9)-12+i-1]
    submission[lll[i]][9] = x10[len(x10)-12+i-1]

# %%
submission
# Out:
#                                  Generic LookupKeys 2019-10-01 00:00:00  \
# 0                       Leopard Volume Closing Base            -1.38438
# 1                            Leopard Volume Leavers           -0.714492
# 2                         Leopard Volume Gross Adds           -0.200817
# 3                       Panther Volume Closing Base             1.49108
# 4                            Panther Volume Leavers             1.46652
# 5                         Panther Volume Gross Adds             1.72247
# 6                         Hyena Volume Closing Base             1.15015
# 7                              Hyena Volume Leavers             1.64355
# 8                           Hyena Volume Gross Adds             1.09883
# 9   Panther - Leopard - Hyena Revenue Total Revenue           0.0461177
#
#   2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# 0            -1.42958            -1.47478            -1.51998
# ...

# %%
submission.to_excel('Predictions.xlsx',index = None)

# %%
rob_1.to_csv('robust/submission1.csv',index = None)
rob_2.to_csv('robust/submission2.csv',index = None)
rob_3.to_csv('robust/submission3.csv',index = None)
rob_4.to_csv('robust/submission4.csv',index = None)
rob_5.to_csv('robust/submission5.csv',index = None)
rob_6.to_csv('robust/submission6.csv',index = None)
rob_7.to_csv('robust/submission7.csv',index = None)
rob_8.to_csv('robust/submission8.csv',index = None)
rob_9.to_csv('robust/submission9.csv',index = None)
rob_10.to_csv('robust/submission10.csv',index = None)
rob_11.to_csv('robust/submission11.csv',index = None)
rob_12.to_csv('robust/submission12.csv',index = None)

# %%
yyy
# Out:
# [' Leopard Volume Closing Base',
#  ' Leopard Volume Leavers',
#  ' Leopard Volume Gross Adds',
#  ' Panther Volume Closing Base',
#  ' Panther Volume Leavers',
#  ' Panther Volume Gross Adds',
#  ' Hyena Volume Closing Base',
#  ' Hyena Volume Leavers',
#  ' Hyena Volume Gross Adds',
#  ' Panther - Leopard - Hyena Revenue Total Revenue']
